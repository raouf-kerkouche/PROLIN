# %%
import pickle
import numpy as np
import seaborn as sns
import pandas as pd
import copy

# %% [markdown]
# # MIA

# %%
#MNIST

with open('f1_scores-mnist_300_50_0.2_30_6000_5_2_mia_check.pkl', 'rb') as f:
    tmp = pickle.load(f)
    
labels_3_mnist, data_3_mnist = zip(*tmp.items())

with open('f1_scores-mnist_300_50_0.2_20_6000_5_2_mia_check.pkl', 'rb') as f:
    tmp = pickle.load(f)
    
labels_2_mnist, data_2_mnist = zip(*tmp.items())

with open('f1_scores-mnist_300_50_0.2_10_6000_5_2_mia_check.pkl', 'rb') as f:
    tmp = pickle.load(f)
    
labels_1_mnist, data_1_mnist = zip(*tmp.items())

# Fashion-MNIST

with open('f1_scores-fmnist_300_50_0.2_30_6000_5_2_mia_check.pkl', 'rb') as f:
    tmp = pickle.load(f)
    
labels_3_fmnist, data_3_fmnist = zip(*tmp.items())

with open('f1_scores-fmnist_300_50_0.2_20_6000_5_2_mia_check.pkl', 'rb') as f:
    tmp = pickle.load(f)
    
labels_2_fmnist, data_2_fmnist = zip(*tmp.items())

with open('f1_scores-fmnist_300_50_0.2_10_6000_5_2_mia_check.pkl', 'rb') as f:
    tmp = pickle.load(f)
    
labels_1_fmnist, data_1_fmnist = zip(*tmp.items())

# CIFAR-10

with open('f1_scores-cifar_300_50_0.2_50_5000_5_2_mia_check.pkl', 'rb') as f:
    tmp = pickle.load(f)
    
labels_2_cifar10, data_2_cifar10 = zip(*tmp.items())

with open('f1_scores-cifar_300_50_0.2_25_5000_5_2_mia_check.pkl', 'rb') as f:
    tmp = pickle.load(f)
    
labels_1_cifar10, data_1_cifar10 = zip(*tmp.items())

# %%
len(data_1_cifar10[0])
# Out:
# 29

# %%
labels_1_cifar10
# Out:
# ('OLS_simple',
#  'OLS',
#  'WLS_simple',
#  'WLS',
#  'REG_simple',
#  'REG',
#  'Baseline',
#  'EM')

# %%
data_1_cifar10
# Out:
# (array([0.31481481, 0.58888889, 0.64646465, 0.64018219, 0.21731015,
#         0.4027451 , 0.53296703, 0.69191919, 0.6290107 , 0.72366522,
#         0.78593629, 0.81118881, 0.7965368 , 0.85858586, 0.91414141,
#         0.85858586, 0.86247086, 0.83721834, 0.73038073, 0.73358586,
#         0.73214286, 0.70423694, 0.73038073, 0.71572872, 0.70779221,
#         0.69191919, 0.68211527, 0.65171451, 0.60136452]),
#  array([0.33333333, 0.54343434, 0.64646465, 0.65407108, 0.06666667,
#         0.40718954, 0.53296703, 0.6780303 , 0.6290107 , 0.7022977 ,
#         0.78593629, 0.81118881, 0.77128427, 0.85858586, 0.91414141,
#         0.85858586, 0.83721834, 0.81585082, 0.71649184, 0.71649184,
#         0.73214286, 0.70423694, 0.71649184, 0.70183983, 0.70779221,
#         0.69191919, 0.69191919, 0.65171451, 0.64369256]),
#  array([0.31481481, 0.58888889, 0.64646465, 0.65407108, 0.21731015,
#         0.4027451 , 0.53296703, 0.69191919, 0.6290107 , 0.72366522,
# ...

# %%
# https://blog.finxter.com/matplotlib-subplots/
# https://www.edureka.co/community/68584/how-to-make-single-legend-for-many-subplots-with-matplotlib
# https://www.codegrepper.com/code-examples/whatever/matplotlib+one+legend+for+all+subplots
# https://www.delftstack.com/fr/howto/matplotlib/how-to-make-a-single-legend-for-all-subplots-in-matplotlib/
# color: https://www.geeksforgeeks.org/how-to-create-a-single-legend-for-all-subplots-in-matplotlib/

# Import necessary modules and (optionally) set Seaborn style
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
from matplotlib import rc,rcParams

# choose style for plots
sns.set_style("darkgrid")

rc('font', weight='bold')


plt.rcParams.update({
    #'figure.figsize': (W, W/(4/3)),     # 4:3 aspect ratio
    'font.size' : 15,                   # Set font size to 11pt
    'axes.labelsize': 15,               # -> axis labels
    'legend.fontsize': 15,              # -> legends
    'xtick.labelsize':15,
    'ytick.labelsize':15,
    'font.family': 'fontenc',
    'font.weight': 'bold',
    'axes.titleweight': 'bold',
    'axes.labelweight': 'bold',
    'figure.titleweight': 'bold',
    'text.usetex': True,
    'axes.titlesize': 15.0,
    'text.latex.preamble': (            # LaTeX preamble
        r'\usepackage[T1]{fontenc}'
        # ... more packages if needed
    )
})

#plt.rcParams["font.weight"] = "bold"
#plt.rcParams["axes.labelweight"] = "bold"

# Generate Figure object and Axes object with shape 3x1
fig, axes = plt.subplots(figsize=(15,10),nrows=3, ncols=3)

#axes[0].set_xlim([1, 205])

#########################################################################################################
###################################MNIST-MIA#############################################################


# Access first Subplot and plot linear numbers
axes[0,0].plot(np.arange(10,(len(data_1_mnist[0])+1)*10,10),data_1_mnist[0], label=labels_1_mnist[0],color='red')
axes[0,0].plot(np.arange(10,(len(data_1_mnist[0])+1)*10,10),data_1_mnist[4], label=labels_1_mnist[4],color='blue')
#axes[0,0].plot(np.arange(10,(len(data_1_mnist[0])+1)*10,10),data_1_mnist[5], label=labels_1_mnist[5],color='orange')
axes[0,0].plot(np.arange(10,(len(data_1_mnist[0])+1)*10,10),data_1_mnist[6], label=labels_1_mnist[6],color='black')
axes[0,0].plot(np.arange(10,(len(data_1_mnist[0])+1)*10,10),data_1_mnist[7], label=labels_1_mnist[7],color='green')
axes[0,0].title.set_text(r'\textbf{(a) MNIST, Dataset size=10}')


# Access first Subplot and plot linear numbers
axes[0,1].plot(np.arange(10,(len(data_2_mnist[0])+1)*10,10),data_2_mnist[0], label=labels_2_mnist[0],color='red')
axes[0,1].plot(np.arange(10,(len(data_2_mnist[0])+1)*10,10),data_2_mnist[4], label=labels_2_mnist[4],color='blue')
#axes[0,1].plot(np.arange(10,(len(data_2_mnist[0])+1)*10,10),data_2_mnist[5], label=labels_2_mnist[5],color='orange')
axes[0,1].plot(np.arange(10,(len(data_2_mnist[0])+1)*10,10),data_2_mnist[6], label=labels_2_mnist[6],color='black')
axes[0,1].plot(np.arange(10,(len(data_2_mnist[0])+1)*10,10),data_2_mnist[7], label=labels_2_mnist[7],color='green')
axes[0,1].title.set_text(r'\textbf{(b) MNIST, Dataset size=20}')


# Access first Subplot and plot linear numbers
axes[0,2].plot(np.arange(10,(len(data_3_mnist[0])+1)*10,10),data_3_mnist[0], label=labels_3_mnist[0],color='red')
axes[0,2].plot(np.arange(10,(len(data_3_mnist[0])+1)*10,10),data_3_mnist[4], label=labels_3_mnist[4],color='blue')
#axes[0,2].plot(np.arange(10,(len(data_3_mnist[0])+1)*10,10),data_3_mnist[5], label=labels_3_mnist[5],color='orange')
axes[0,2].plot(np.arange(10,(len(data_3_mnist[0])+1)*10,10),data_3_mnist[6], label=labels_3_mnist[6],color='black')
axes[0,2].plot(np.arange(10,(len(data_3_mnist[0])+1)*10,10),data_3_mnist[7], label=labels_3_mnist[7],color='green')
axes[0,2].title.set_text(r'\textbf{(c) MNIST, Dataset size=30}')

#########################################################################################################
###################################FMNIST-MIA#############################################################


# Access first Subplot and plot linear numbers
axes[1,0].plot(np.arange(10,(len(data_1_fmnist[0])+1)*10,10),data_1_fmnist[0], label=labels_1_fmnist[0],color='red')
axes[1,0].plot(np.arange(10,(len(data_1_fmnist[0])+1)*10,10),data_1_fmnist[4], label=labels_1_fmnist[4],color='blue')
#axes[1,0].plot(np.arange(10,(len(data_1_fmnist[0])+1)*10,10),data_1_fmnist[5], label=labels_1_fmnist[5],color='orange')
axes[1,0].plot(np.arange(10,(len(data_1_fmnist[0])+1)*10,10),data_1_fmnist[6], label=labels_1_fmnist[6],color='black')
axes[1,0].plot(np.arange(10,(len(data_1_fmnist[0])+1)*10,10),data_1_fmnist[7], label=labels_1_fmnist[7],color='green')
axes[1,0].title.set_text(r'\textbf{(d) FMNIST, Dataset size=10}')


# Access first Subplot and plot linear numbers
axes[1,1].plot(np.arange(10,(len(data_2_fmnist[0])+1)*10,10),data_2_fmnist[0], label=labels_2_fmnist[0],color='red')
axes[1,1].plot(np.arange(10,(len(data_2_fmnist[0])+1)*10,10),data_2_fmnist[4], label=labels_2_fmnist[4],color='blue')
#axes[1,1].plot(np.arange(10,(len(data_2_fmnist[0])+1)*10,10),data_2_fmnist[5], label=labels_2_fmnist[5],color='orange')
axes[1,1].plot(np.arange(10,(len(data_2_fmnist[0])+1)*10,10),data_2_fmnist[6], label=labels_2_fmnist[6],color='black')
axes[1,1].plot(np.arange(10,(len(data_2_fmnist[0])+1)*10,10),data_2_fmnist[7], label=labels_2_fmnist[7],color='green')
axes[1,1].title.set_text(r'\textbf{(e) FMNIST, Dataset size=20}')


# Access first Subplot and plot linear numbers
axes[1,2].plot(np.arange(10,(len(data_3_fmnist[0])+1)*10,10),data_3_fmnist[0], label=labels_3_fmnist[0],color='red')
axes[1,2].plot(np.arange(10,(len(data_3_fmnist[0])+1)*10,10),data_3_fmnist[4], label=labels_3_fmnist[4],color='blue')
#axes[1,2].plot(np.arange(10,(len(data_3_fmnist[0])+1)*10,10),data_3_fmnist[5], label=labels_3_fmnist[5],color='orange')
axes[1,2].plot(np.arange(10,(len(data_3_fmnist[0])+1)*10,10),data_3_fmnist[6], label=labels_3_fmnist[6],color='black')
axes[1,2].plot(np.arange(10,(len(data_3_fmnist[0])+1)*10,10),data_3_fmnist[7], label=labels_3_fmnist[7],color='green')
axes[1,2].title.set_text(r'\textbf{(f) FMNIST, Dataset size=30}')


#########################################################################################################
###################################CIFAR-10#############################################################


# Access first Subplot and plot linear numbers
axes[2,0].plot(np.arange(10,(len(data_1_cifar10[0])+1)*10,10),data_1_cifar10[0], label=labels_1_cifar10[0],color='red')
axes[2,0].plot(np.arange(10,(len(data_1_cifar10[0])+1)*10,10),data_1_cifar10[4], label=labels_1_cifar10[4],color='blue')
#axes[2,0].plot(np.arange(10,(len(data_1_cifar10[0])+1)*10,10),data_1_cifar10[5], label=labels_1_cifar10[5],color='orange')
axes[2,0].plot(np.arange(10,(len(data_1_cifar10[0])+1)*10,10),data_1_cifar10[6], label=labels_1_cifar10[6],color='black')
axes[2,0].plot(np.arange(10,(len(data_1_cifar10[0])+1)*10,10),data_1_cifar10[7], label=labels_1_cifar10[7],color='green')
axes[2,0].title.set_text(r'\textbf{(g) CIFAR-10, Dataset size=25}')


# Access first Subplot and plot linear numbers
axes[2,1].plot(np.arange(10,(len(data_2_cifar10[0])+1)*10,10),data_2_cifar10[0], label=labels_2_cifar10[0],color='red')
axes[2,1].plot(np.arange(10,(len(data_2_cifar10[0])+1)*10,10),data_2_cifar10[4], label=labels_2_cifar10[4],color='blue')
#axes[2,1].plot(np.arange(10,(len(data_2_cifar10[0])+1)*10,10),data_2_cifar10[5], label=labels_2_cifar10[5],color='orange')
axes[2,1].plot(np.arange(10,(len(data_2_cifar10[0])+1)*10,10),data_2_cifar10[6], label=labels_2_cifar10[6],color='black')
axes[2,1].plot(np.arange(10,(len(data_2_cifar10[0])+1)*10,10),data_2_cifar10[7], label=labels_2_cifar10[7],color='green')
axes[2,1].title.set_text(r'\textbf{(h) CIFAR-10, Dataset size=50}')



axes[-1, -1].axis('off')



axes[0,0].set_xlabel('Round')
axes[0,1].set_xlabel('Round')
axes[0,2].set_xlabel('Round')
axes[1,0].set_xlabel('Round')
axes[1,1].set_xlabel('Round')
axes[1,2].set_xlabel('Round')
axes[2,0].set_xlabel('Round')
axes[2,1].set_xlabel('Round')
axes[0,0].set_ylabel('F1-score')
axes[1,0].set_ylabel('F1-score')
axes[2,0].set_ylabel('F1-score')

handles, labels = axes[0,0].get_legend_handles_labels()

labels=["OLS","REG","BASELINE","PROLIN"]

#labels[0]='OLS'
#labels[1]='REG'

fig.legend(handles, labels, loc='lower right', bbox_to_anchor=(0.9, 0.1), ncol=1)


plt.tight_layout()

plt.savefig('MIA.pdf',bbox_inches='tight')

plt.show()

# %% [markdown]
# # INV:

# %%
#MNIST

with open('f1_scores-mnist_300_50_0.2_30_6000_5_2_inv_check.pkl', 'rb') as f:
    tmp = pickle.load(f)
    
labels_3_mnist, data_3_mnist = zip(*tmp.items())

with open('f1_scores-mnist_300_50_0.2_20_6000_5_2_inv_check.pkl', 'rb') as f:
    tmp = pickle.load(f)
    
labels_2_mnist, data_2_mnist = zip(*tmp.items())

with open('f1_scores-mnist_300_50_0.2_10_6000_5_2_inv_check.pkl', 'rb') as f:
    tmp = pickle.load(f)
    
labels_1_mnist, data_1_mnist = zip(*tmp.items())

# Fashion-MNIST

with open('f1_scores-fmnist_300_50_0.2_30_6000_5_2_inv_check.pkl', 'rb') as f:
    tmp = pickle.load(f)
    
labels_3_fmnist, data_3_fmnist = zip(*tmp.items())

with open('f1_scores-fmnist_300_50_0.2_20_6000_5_2_inv_check.pkl', 'rb') as f:
    tmp = pickle.load(f)
    
labels_2_fmnist, data_2_fmnist = zip(*tmp.items())

with open('f1_scores-fmnist_300_50_0.2_10_6000_5_2_inv_check.pkl', 'rb') as f:
    tmp = pickle.load(f)
    
labels_1_fmnist, data_1_fmnist = zip(*tmp.items())

# CIFAR-10

with open('f1_scores-cifar_300_50_0.2_50_5000_5_2_inv_check.pkl', 'rb') as f:
    tmp = pickle.load(f)
    
labels_2_cifar10, data_2_cifar10 = zip(*tmp.items())

with open('f1_scores-cifar_300_50_0.2_25_5000_5_2_inv_check.pkl', 'rb') as f:
    tmp = pickle.load(f)
    
labels_1_cifar10, data_1_cifar10 = zip(*tmp.items())

# %%
labels_1_cifar10
# Out:
# ('OLS_simple',
#  'OLS',
#  'WLS_simple',
#  'WLS',
#  'REG_simple',
#  'REG',
#  'Baseline',
#  'EM')

# %%
# https://blog.finxter.com/matplotlib-subplots/
# https://www.edureka.co/community/68584/how-to-make-single-legend-for-many-subplots-with-matplotlib
# https://www.codegrepper.com/code-examples/whatever/matplotlib+one+legend+for+all+subplots
# https://www.delftstack.com/fr/howto/matplotlib/how-to-make-a-single-legend-for-all-subplots-in-matplotlib/
# color: https://www.geeksforgeeks.org/how-to-create-a-single-legend-for-all-subplots-in-matplotlib/

# Import necessary modules and (optionally) set Seaborn style
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
from matplotlib import rc,rcParams

# choose style for plots
sns.set_style("darkgrid")

rc('font', weight='bold')


plt.rcParams.update({
    #'figure.figsize': (W, W/(4/3)),     # 4:3 aspect ratio
    'font.size' : 15,                   # Set font size to 11pt
    'axes.labelsize': 15,               # -> axis labels
    'legend.fontsize': 15,              # -> legends
    'xtick.labelsize':15,
    'ytick.labelsize':15,
    'font.family': 'fontenc',
    'font.weight': 'bold',
    'axes.titleweight': 'bold',
    'axes.labelweight': 'bold',
    'figure.titleweight': 'bold',
    'text.usetex': True,
    'axes.titlesize': 15.0,
    'text.latex.preamble': (            # LaTeX preamble
        r'\usepackage[T1]{fontenc}'
        # ... more packages if needed
    )
})

#plt.rcParams["font.weight"] = "bold"
#plt.rcParams["axes.labelweight"] = "bold"

# Generate Figure object and Axes object with shape 3x1
fig, axes = plt.subplots(figsize=(15,10),nrows=3, ncols=3)

#axes[0].set_xlim([1, 205])

#########################################################################################################
###################################MNIST-MIA#############################################################


# Access first Subplot and plot linear numbers
axes[0,0].plot(np.arange(10,(len(data_1_mnist[0])+1)*10,10),data_1_mnist[0], label=labels_1_mnist[0],color='red')
axes[0,0].plot(np.arange(10,(len(data_1_mnist[0])+1)*10,10),data_1_mnist[4], label=labels_1_mnist[4],color='blue')
#axes[0,0].plot(np.arange(10,(len(data_1_mnist[0])+1)*10,10),data_1_mnist[5], label=labels_1_mnist[5],color='orange')
axes[0,0].plot(np.arange(10,(len(data_1_mnist[0])+1)*10,10),data_1_mnist[6], label=labels_1_mnist[6],color='black')
axes[0,0].plot(np.arange(10,(len(data_1_mnist[0])+1)*10,10),data_1_mnist[7], label=labels_1_mnist[7],color='green')
axes[0,0].title.set_text(r'\textbf{(a) MNIST, Dataset size=10}')


# Access first Subplot and plot linear numbers
axes[0,1].plot(np.arange(10,(len(data_2_mnist[0])+1)*10,10),data_2_mnist[0], label=labels_2_mnist[0],color='red')
axes[0,1].plot(np.arange(10,(len(data_2_mnist[0])+1)*10,10),data_2_mnist[4], label=labels_2_mnist[4],color='blue')
#axes[0,1].plot(np.arange(10,(len(data_2_mnist[0])+1)*10,10),data_2_mnist[5], label=labels_2_mnist[5],color='orange')
axes[0,1].plot(np.arange(10,(len(data_2_mnist[0])+1)*10,10),data_2_mnist[6], label=labels_2_mnist[6],color='black')
axes[0,1].plot(np.arange(10,(len(data_2_mnist[0])+1)*10,10),data_2_mnist[7], label=labels_2_mnist[7],color='green')
axes[0,1].title.set_text(r'\textbf{(b) MNIST, Dataset size=20}')


# Access first Subplot and plot linear numbers
axes[0,2].plot(np.arange(10,(len(data_3_mnist[0])+1)*10,10),data_3_mnist[0], label=labels_3_mnist[0],color='red')
axes[0,2].plot(np.arange(10,(len(data_3_mnist[0])+1)*10,10),data_3_mnist[4], label=labels_3_mnist[4],color='blue')
#axes[0,2].plot(np.arange(10,(len(data_3_mnist[0])+1)*10,10),data_3_mnist[5], label=labels_3_mnist[5],color='orange')
axes[0,2].plot(np.arange(10,(len(data_3_mnist[0])+1)*10,10),data_3_mnist[6], label=labels_3_mnist[6],color='black')
axes[0,2].plot(np.arange(10,(len(data_3_mnist[0])+1)*10,10),data_3_mnist[7], label=labels_3_mnist[7],color='green')
axes[0,2].title.set_text(r'\textbf{(c) MNIST, Dataset size=30}')

#########################################################################################################
###################################FMNIST-MIA#############################################################


# Access first Subplot and plot linear numbers
axes[1,0].plot(np.arange(10,(len(data_1_fmnist[0])+1)*10,10),data_1_fmnist[0], label=labels_1_fmnist[0],color='red')
axes[1,0].plot(np.arange(10,(len(data_1_fmnist[0])+1)*10,10),data_1_fmnist[4], label=labels_1_fmnist[4],color='blue')
#axes[1,0].plot(np.arange(10,(len(data_1_fmnist[0])+1)*10,10),data_1_fmnist[5], label=labels_1_fmnist[5],color='orange')
axes[1,0].plot(np.arange(10,(len(data_1_fmnist[0])+1)*10,10),data_1_fmnist[6], label=labels_1_fmnist[6],color='black')
axes[1,0].plot(np.arange(10,(len(data_1_fmnist[0])+1)*10,10),data_1_fmnist[7], label=labels_1_fmnist[7],color='green')
axes[1,0].title.set_text(r'\textbf{(d) FMNIST, Dataset size=10}')


# Access first Subplot and plot linear numbers
axes[1,1].plot(np.arange(10,(len(data_2_fmnist[0])+1)*10,10),data_2_fmnist[0], label=labels_2_fmnist[0],color='red')
axes[1,1].plot(np.arange(10,(len(data_2_fmnist[0])+1)*10,10),data_2_fmnist[4], label=labels_2_fmnist[4],color='blue')
#axes[1,1].plot(np.arange(10,(len(data_2_fmnist[0])+1)*10,10),data_2_fmnist[5], label=labels_2_fmnist[5],color='orange')
axes[1,1].plot(np.arange(10,(len(data_2_fmnist[0])+1)*10,10),data_2_fmnist[6], label=labels_2_fmnist[6],color='black')
axes[1,1].plot(np.arange(10,(len(data_2_fmnist[0])+1)*10,10),data_2_fmnist[7], label=labels_2_fmnist[7],color='green')
axes[1,1].title.set_text(r'\textbf{(e) FMNIST, Dataset size=20}')


# Access first Subplot and plot linear numbers
axes[1,2].plot(np.arange(10,(len(data_3_fmnist[0])+1)*10,10),data_3_fmnist[0], label=labels_3_fmnist[0],color='red')
axes[1,2].plot(np.arange(10,(len(data_3_fmnist[0])+1)*10,10),data_3_fmnist[4], label=labels_3_fmnist[4],color='blue')
#axes[1,2].plot(np.arange(10,(len(data_3_fmnist[0])+1)*10,10),data_3_fmnist[5], label=labels_3_fmnist[5],color='orange')
axes[1,2].plot(np.arange(10,(len(data_3_fmnist[0])+1)*10,10),data_3_fmnist[6], label=labels_3_fmnist[6],color='black')
axes[1,2].plot(np.arange(10,(len(data_3_fmnist[0])+1)*10,10),data_3_fmnist[7], label=labels_3_fmnist[7],color='green')
axes[1,2].title.set_text(r'\textbf{(f) FMNIST, Dataset size=30}')


#########################################################################################################
###################################CIFAR-10#############################################################


# Access first Subplot and plot linear numbers
axes[2,0].plot(np.arange(10,(len(data_1_cifar10[0])+1)*10,10),data_1_cifar10[0], label=labels_1_cifar10[0],color='red')
axes[2,0].plot(np.arange(10,(len(data_1_cifar10[0])+1)*10,10),data_1_cifar10[4], label=labels_1_cifar10[4],color='blue')
#axes[2,0].plot(np.arange(10,(len(data_1_cifar10[0])+1)*10,10),data_1_cifar10[5], label=labels_1_cifar10[5],color='orange')
axes[2,0].plot(np.arange(10,(len(data_1_cifar10[0])+1)*10,10),data_1_cifar10[6], label=labels_1_cifar10[6],color='black')
axes[2,0].plot(np.arange(10,(len(data_1_cifar10[0])+1)*10,10),data_1_cifar10[7], label=labels_1_cifar10[7],color='green')
axes[2,0].title.set_text(r'\textbf{(g) CIFAR-10, Dataset size=25}')


# Access first Subplot and plot linear numbers
axes[2,1].plot(np.arange(10,(len(data_2_cifar10[0])+1)*10,10),data_2_cifar10[0], label=labels_2_cifar10[0],color='red')
axes[2,1].plot(np.arange(10,(len(data_2_cifar10[0])+1)*10,10),data_2_cifar10[4], label=labels_2_cifar10[4],color='blue')
#axes[2,1].plot(np.arange(10,(len(data_2_cifar10[0])+1)*10,10),data_2_cifar10[5], label=labels_2_cifar10[5],color='orange')
axes[2,1].plot(np.arange(10,(len(data_2_cifar10[0])+1)*10,10),data_2_cifar10[6], label=labels_2_cifar10[6],color='black')
axes[2,1].plot(np.arange(10,(len(data_2_cifar10[0])+1)*10,10),data_2_cifar10[7], label=labels_2_cifar10[7],color='green')
axes[2,1].title.set_text(r'\textbf{(h) CIFAR-10, Dataset size=50}')



axes[-1, -1].axis('off')



axes[0,0].set_xlabel('Round')
axes[0,1].set_xlabel('Round')
axes[0,2].set_xlabel('Round')
axes[1,0].set_xlabel('Round')
axes[1,1].set_xlabel('Round')
axes[1,2].set_xlabel('Round')
axes[2,0].set_xlabel('Round')
axes[2,1].set_xlabel('Round')
axes[0,0].set_ylabel('F1-score')
axes[1,0].set_ylabel('F1-score')
axes[2,0].set_ylabel('F1-score')

handles, labels = axes[0,0].get_legend_handles_labels()

labels=["OLS","REG","BASELINE","PROLIN"]

#labels[0]='OLS'
#labels[1]='REG'

fig.legend(handles, labels, loc='lower right', bbox_to_anchor=(0.9, 0.1), ncol=1)


plt.tight_layout()

plt.savefig('INV.pdf',bbox_inches='tight')

plt.show()

# %% [markdown]
# # AGA

# %%
#MNIST



with open('f1_scores-mnist_300_50_0.2_30_6000_5_2_aga_check.pkl', 'rb') as f:
    tmp = pickle.load(f)
    
labels_3_mnist, data_3_mnist = zip(*tmp.items())

with open('f1_scores-mnist_300_50_0.2_20_6000_5_2_aga_check.pkl', 'rb') as f:
    tmp = pickle.load(f)
    
labels_2_mnist, data_2_mnist = zip(*tmp.items())

with open('f1_scores-mnist_300_50_0.2_10_6000_5_2_aga_check.pkl', 'rb') as f:
    tmp = pickle.load(f)
    
labels_1_mnist, data_1_mnist = zip(*tmp.items())


# Fashion-MNIST

with open('f1_scores-fmnist_300_50_0.2_30_6000_5_2_aga_check.pkl', 'rb') as f:
    tmp = pickle.load(f)
    
labels_3_fmnist, data_3_fmnist = zip(*tmp.items())

with open('f1_scores-fmnist_300_50_0.2_20_6000_5_2_aga_check.pkl', 'rb') as f:
    tmp = pickle.load(f)
    
labels_2_fmnist, data_2_fmnist = zip(*tmp.items())

with open('f1_scores-fmnist_300_50_0.2_10_6000_5_2_aga_check.pkl', 'rb') as f:
    tmp = pickle.load(f)
    
labels_1_fmnist, data_1_fmnist = zip(*tmp.items())

# CIFAR-10

with open('f1_scores-cifar_300_50_0.2_50_5000_5_2_aga_check.pkl', 'rb') as f:
    tmp = pickle.load(f)
    
labels_2_cifar10, data_2_cifar10 = zip(*tmp.items())

with open('f1_scores-cifar_300_50_0.2_25_5000_5_2_aga_check.pkl', 'rb') as f:
    tmp = pickle.load(f)
    
labels_1_cifar10, data_1_cifar10 = zip(*tmp.items())

# %%
labels_1_cifar10
# Out:
# ('OLS_simple',
#  'OLS',
#  'WLS_simple',
#  'WLS',
#  'REG_simple',
#  'REG',
#  'Baseline',
#  'EM')

# %%
np.max(data_1_cifar10[-2]),np.argmax(data_1_cifar10[-2])
# Out:
# (1.0, 28)

# %%
data_1_cifar10
# Out:
# (array([0.3452381 , 0.6040404 , 0.62150921, 0.51072125, 0.17820111,
#         0.35081871, 0.40025575, 0.45764143, 0.579997  , 0.57142857,
#         0.6037037 , 0.61862321, 0.6114082 , 0.61428571, 0.60962663,
#         0.63575606, 0.72100122, 0.81196581, 0.81196581, 0.8015873 ,
#         0.82683983, 0.78593629, 0.77128427, 0.77128427, 0.81118881,
#         0.82323232, 0.8030303 , 0.76068376, 0.76923077]),
#  array([0.3452381 , 0.58585859, 0.64171123, 0.51943584, 0.04444444,
#         0.3389899 , 0.37427536, 0.46341344, 0.60136452, 0.58974359,
#         0.6037037 , 0.65686275, 0.65686275, 0.62222222, 0.66388889,
#         0.69607843, 0.73931624, 0.83721834, 0.7979798 , 0.82683983,
#         0.87179487, 0.83333333, 0.78593629, 0.78593629, 0.81118881,
#         0.84848485, 0.8030303 , 0.82828283, 0.8030303 ]),
#  array([0.30555556, 0.62626263, 0.62150921, 0.51943584, 0.17820111,
#         0.35081871, 0.40025575, 0.45764143, 0.579997  , 0.57142857,
# ...

# %%
# https://blog.finxter.com/matplotlib-subplots/
# https://www.edureka.co/community/68584/how-to-make-single-legend-for-many-subplots-with-matplotlib
# https://www.codegrepper.com/code-examples/whatever/matplotlib+one+legend+for+all+subplots
# https://www.delftstack.com/fr/howto/matplotlib/how-to-make-a-single-legend-for-all-subplots-in-matplotlib/
# color: https://www.geeksforgeeks.org/how-to-create-a-single-legend-for-all-subplots-in-matplotlib/

# Import necessary modules and (optionally) set Seaborn style
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
from matplotlib import rc,rcParams

# choose style for plots
sns.set_style("darkgrid")

rc('font', weight='bold')


plt.rcParams.update({
    #'figure.figsize': (W, W/(4/3)),     # 4:3 aspect ratio
    'font.size' : 15,                   # Set font size to 11pt
    'axes.labelsize': 15,               # -> axis labels
    'legend.fontsize': 15,              # -> legends
    'xtick.labelsize':15,
    'ytick.labelsize':15,
    'font.family': 'fontenc',
    'font.weight': 'bold',
    'axes.titleweight': 'bold',
    'axes.labelweight': 'bold',
    'figure.titleweight': 'bold',
    'text.usetex': True,
    'axes.titlesize': 15.0,
    'text.latex.preamble': (            # LaTeX preamble
        r'\usepackage[T1]{fontenc}'
        # ... more packages if needed
    )
})

#plt.rcParams["font.weight"] = "bold"
#plt.rcParams["axes.labelweight"] = "bold"

# Generate Figure object and Axes object with shape 3x1
fig, axes = plt.subplots(figsize=(15,10),nrows=3, ncols=3)

#axes[0].set_xlim([1, 205])

#########################################################################################################
###################################MNIST-MIA#############################################################


# Access first Subplot and plot linear numbers
axes[0,0].plot(np.arange(10,(len(data_1_mnist[0])+1)*10,10),data_1_mnist[0], label=labels_1_mnist[0],color='red')
axes[0,0].plot(np.arange(10,(len(data_1_mnist[0])+1)*10,10),data_1_mnist[4], label=labels_1_mnist[4],color='blue')
#axes[0,0].plot(np.arange(10,(len(data_1_mnist[0])+1)*10,10),data_1_mnist[5], label=labels_1_mnist[5],color='orange')
axes[0,0].plot(np.arange(10,(len(data_1_mnist[0])+1)*10,10),data_1_mnist[6], label=labels_1_mnist[6],color='black')
axes[0,0].plot(np.arange(10,(len(data_1_mnist[0])+1)*10,10),data_1_mnist[7], label=labels_1_mnist[7],color='green')
axes[0,0].title.set_text(r'\textbf{(a) MNIST, Dataset size=10}')


# Access first Subplot and plot linear numbers
axes[0,1].plot(np.arange(10,(len(data_2_mnist[0])+1)*10,10),data_2_mnist[0], label=labels_2_mnist[0],color='red')
axes[0,1].plot(np.arange(10,(len(data_2_mnist[0])+1)*10,10),data_2_mnist[4], label=labels_2_mnist[4],color='blue')
#axes[0,1].plot(np.arange(10,(len(data_2_mnist[0])+1)*10,10),data_2_mnist[5], label=labels_2_mnist[5],color='orange')
axes[0,1].plot(np.arange(10,(len(data_2_mnist[0])+1)*10,10),data_2_mnist[6], label=labels_2_mnist[6],color='black')
axes[0,1].plot(np.arange(10,(len(data_2_mnist[0])+1)*10,10),data_2_mnist[7], label=labels_2_mnist[7],color='green')
axes[0,1].title.set_text(r'\textbf{(b) MNIST, Dataset size=20}')


# Access first Subplot and plot linear numbers
axes[0,2].plot(np.arange(10,(len(data_3_mnist[0])+1)*10,10),data_3_mnist[0], label=labels_3_mnist[0],color='red')
axes[0,2].plot(np.arange(10,(len(data_3_mnist[0])+1)*10,10),data_3_mnist[4], label=labels_3_mnist[4],color='blue')
#axes[0,2].plot(np.arange(10,(len(data_3_mnist[0])+1)*10,10),data_3_mnist[5], label=labels_3_mnist[5],color='orange')
axes[0,2].plot(np.arange(10,(len(data_3_mnist[0])+1)*10,10),data_3_mnist[6], label=labels_3_mnist[6],color='black')
axes[0,2].plot(np.arange(10,(len(data_3_mnist[0])+1)*10,10),data_3_mnist[7], label=labels_3_mnist[7],color='green')
axes[0,2].title.set_text(r'\textbf{(c) MNIST, Dataset size=30}')

#########################################################################################################
###################################FMNIST-MIA#############################################################


# Access first Subplot and plot linear numbers
axes[1,0].plot(np.arange(10,(len(data_1_fmnist[0])+1)*10,10),data_1_fmnist[0], label=labels_1_fmnist[0],color='red')
axes[1,0].plot(np.arange(10,(len(data_1_fmnist[0])+1)*10,10),data_1_fmnist[4], label=labels_1_fmnist[4],color='blue')
#axes[1,0].plot(np.arange(10,(len(data_1_fmnist[0])+1)*10,10),data_1_fmnist[5], label=labels_1_fmnist[5],color='orange')
axes[1,0].plot(np.arange(10,(len(data_1_fmnist[0])+1)*10,10),data_1_fmnist[6], label=labels_1_fmnist[6],color='black')
axes[1,0].plot(np.arange(10,(len(data_1_fmnist[0])+1)*10,10),data_1_fmnist[7], label=labels_1_fmnist[7],color='green')
axes[1,0].title.set_text(r'\textbf{(d) FMNIST, Dataset size=10}')


# Access first Subplot and plot linear numbers
axes[1,1].plot(np.arange(10,(len(data_2_fmnist[0])+1)*10,10),data_2_fmnist[0], label=labels_2_fmnist[0],color='red')
axes[1,1].plot(np.arange(10,(len(data_2_fmnist[0])+1)*10,10),data_2_fmnist[4], label=labels_2_fmnist[4],color='blue')
#axes[1,1].plot(np.arange(10,(len(data_2_fmnist[0])+1)*10,10),data_2_fmnist[5], label=labels_2_fmnist[5],color='orange')
axes[1,1].plot(np.arange(10,(len(data_2_fmnist[0])+1)*10,10),data_2_fmnist[6], label=labels_2_fmnist[6],color='black')
axes[1,1].plot(np.arange(10,(len(data_2_fmnist[0])+1)*10,10),data_2_fmnist[7], label=labels_2_fmnist[7],color='green')
axes[1,1].title.set_text(r'\textbf{(e) FMNIST, Dataset size=20}')


# Access first Subplot and plot linear numbers
axes[1,2].plot(np.arange(10,(len(data_3_fmnist[0])+1)*10,10),data_3_fmnist[0], label=labels_3_fmnist[0],color='red')
axes[1,2].plot(np.arange(10,(len(data_3_fmnist[0])+1)*10,10),data_3_fmnist[4], label=labels_3_fmnist[4],color='blue')
#axes[1,2].plot(np.arange(10,(len(data_3_fmnist[0])+1)*10,10),data_3_fmnist[5], label=labels_3_fmnist[5],color='orange')
axes[1,2].plot(np.arange(10,(len(data_3_fmnist[0])+1)*10,10),data_3_fmnist[6], label=labels_3_fmnist[6],color='black')
axes[1,2].plot(np.arange(10,(len(data_3_fmnist[0])+1)*10,10),data_3_fmnist[7], label=labels_3_fmnist[7],color='green')
axes[1,2].title.set_text(r'\textbf{(f) FMNIST, Dataset size=30}')


#########################################################################################################
###################################CIFAR-10#############################################################


# Access first Subplot and plot linear numbers
axes[2,0].plot(np.arange(10,(len(data_1_cifar10[0])+1)*10,10),data_1_cifar10[0], label=labels_1_cifar10[0],color='red')
axes[2,0].plot(np.arange(10,(len(data_1_cifar10[0])+1)*10,10),data_1_cifar10[4], label=labels_1_cifar10[4],color='blue')
#axes[2,0].plot(np.arange(10,(len(data_1_cifar10[0])+1)*10,10),data_1_cifar10[5], label=labels_1_cifar10[5],color='orange')
axes[2,0].plot(np.arange(10,(len(data_1_cifar10[0])+1)*10,10),data_1_cifar10[6], label=labels_1_cifar10[6],color='black')
axes[2,0].plot(np.arange(10,(len(data_1_cifar10[0])+1)*10,10),data_1_cifar10[7], label=labels_1_cifar10[7],color='green')
axes[2,0].title.set_text(r'\textbf{(g) CIFAR-10, Dataset size=25}')


# Access first Subplot and plot linear numbers
axes[2,1].plot(np.arange(10,(len(data_2_cifar10[0])+1)*10,10),data_2_cifar10[0], label=labels_2_cifar10[0],color='red')
axes[2,1].plot(np.arange(10,(len(data_2_cifar10[0])+1)*10,10),data_2_cifar10[4], label=labels_2_cifar10[4],color='blue')
#axes[2,1].plot(np.arange(10,(len(data_2_cifar10[0])+1)*10,10),data_2_cifar10[5], label=labels_2_cifar10[5],color='orange')
axes[2,1].plot(np.arange(10,(len(data_2_cifar10[0])+1)*10,10),data_2_cifar10[6], label=labels_2_cifar10[6],color='black')
axes[2,1].plot(np.arange(10,(len(data_2_cifar10[0])+1)*10,10),data_2_cifar10[7], label=labels_2_cifar10[7],color='green')
axes[2,1].title.set_text(r'\textbf{(h) CIFAR-10, Dataset size=50}')



axes[-1, -1].axis('off')



axes[0,0].set_xlabel('Round')
axes[0,1].set_xlabel('Round')
axes[0,2].set_xlabel('Round')
axes[1,0].set_xlabel('Round')
axes[1,1].set_xlabel('Round')
axes[1,2].set_xlabel('Round')
axes[2,0].set_xlabel('Round')
axes[2,1].set_xlabel('Round')
axes[0,0].set_ylabel('F1-score')
axes[1,0].set_ylabel('F1-score')
axes[2,0].set_ylabel('F1-score')

handles, labels = axes[0,0].get_legend_handles_labels()

labels=["OLS","REG","BASELINE","PROLIN"]

#labels[0]='OLS'
#labels[1]='REG'

fig.legend(handles, labels, loc='lower right', bbox_to_anchor=(0.9, 0.1), ncol=1)


plt.tight_layout()

plt.savefig('AGA.pdf',bbox_inches='tight')

plt.show()
